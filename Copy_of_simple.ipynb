# %% [markdown]
# <a href="https://colab.research.google.com/github/andugulasandhya/Sandhya1331/blob/main/Copy_of_simple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
data=pd.read_csv("/content/archive (11) (1) (1) (2).zip")
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
x = data.drop('Sales' , axis=1).values
y = data['Sales'].values

# %%
data.corr
# Out:
# <bound method DataFrame.corr of         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]>

# %%
x_tv = x[: , 0]

# %%
plt.scatter(x_tv,y)
plt.xlabel('No of advertisements')
plt.ylabel('Value of sales')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.reshape(-1,1)
# Out:
# array([[116. ],
#        [  7.7],
#        [ 23.1],
#        [177. ],
#        [  9.3],
#        [  6.4],
#        [ 43.1],
#        [ 26.7],
#        [ 35.1],
#        [ 62.3],
#        [ 12.6],
#        [ 18.3],
#        [224. ],
#        [  2.4],
#        [ 15.6],
#        [ 38.2],
#        [  3.7],
#        [ 13.8],
#        [ 70.6],
#        [ 16. ],
#        [ 40.8],
#        [147.3],
#        [ 23.9],
#        [ 19.1],
#        [104.6],
#        [  5.7],
#        [ 34.4],
#        [ 76.3],
#        [ 27.5],
#        [ 16. ],
#        [ 78.2],
#        [ 46.8],
#        [ 34.5],
#        [168.4],
#        [  7.1],
#        [ 12.8],
#        [  8.7],
#        [ 48.9],
#        [ 75. ],
#        [  7.8],
#        [ 38.9],
#        [ 50.6],
#        [ 76.4],
#        [  0.8],
#        [ 14.8],
#        [129.4],
#        [  5.7],
#        [ 31.3],
#        [ 73.4],
#        [ 17. ],
#        [ 12.9],
#        [289.7],
#        [ 42.3],
#        [ 51.2],
#        [ 19.6],
# ...

# %%
y_train.reshape(-1,1)
# Out:
# array([[11. ],
#        [14.8],
#        [10.1],
#        [ 9.7],
#        [16.6],
#        [ 7.6],
#        [10.5],
#        [14.6],
#        [10.4],
#        [12. ],
#        [14.6],
#        [16.7],
#        [ 7.2],
#        [ 6.6],
#        [ 9.4],
#        [11. ],
#        [10.9],
#        [25.4],
#        [ 7.6],
#        [16.7],
#        [20. ],
#        [20.5],
#        [11.9],
#        [ 9.2],
#        [17.8],
#        [ 6.6],
#        [20.7],
#        [ 6.7],
#        [14. ],
#        [ 9.5],
#        [10.7],
#        [11.9],
#        [19.9],
#        [17.1],
#        [15.9],
#        [20.9],
#        [15. ],
#        [20.7],
#        [16.7],
#        [21.8],
#        [12. ],
#        [14.2],
#        [10.6],
#        [17.3],
#        [11.9],
#        [20.2],
#        [13.3],
#        [25.4],
#        [10.8],
#        [24.2],
#        [ 5.6],
#        [19.2],
#        [23.8],
#        [17.4],
#        [17.4],
#        [17.3],
#        [12.9],
#        [11.8],
# ...

# %%
x_tv=x_tv.reshape(-1,1)

# %%
y=y.reshape(-1,1)

# %%
x_train.shape,y_train.shape
# Out:
# ((160, 3), (160,))

# %%
reg=linear_model.LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error
y_pred1=reg.predict(x_train)
print(f'Performance on the training data :\n')
print(f'MSE = {mean_squared_error(y_train,y_pred1)}')
# Out:
# Performance on the training data :
#
# MSE = 2.6761426537826685
